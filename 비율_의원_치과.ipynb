# %%
import pandas as pd
import numpy as np

# %%
per = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\make\컬럼6개_비율.csv')
per.drop(['Unnamed: 0','cluster_rate'], axis=1, inplace=True)
per
# Out:
#         출생비_k     사망비_k     혼인비_k     이혼비_k      전입_s      전출_s     동
# 0    0.002442  0.004165  0.001724  0.001867 -1.394382 -1.698988  개포1동
# 1    0.005397  0.002024  0.002166  0.000994  3.622903  0.387324  개포2동
# 2    0.003849  0.002411  0.003849  0.001734  0.595519 -0.178814  개포4동
# 3    0.004232  0.003686  0.005097  0.002048  1.003062  1.526013  논현1동
# 4    0.004864  0.003624  0.004149  0.001907  0.463748  0.793174  논현2동
# ..        ...       ...       ...       ...       ...       ...   ...
# 420  0.006222  0.004741  0.007901  0.002173  0.611642  0.283458  상봉2동
# 421  0.004768  0.006488  0.002475  0.001277  0.212439  0.719442  신내1동
# 422  0.006528  0.006874  0.003659  0.001929 -0.642123 -0.438481  신내2동
# 423  0.006720  0.006053  0.005027  0.001744 -0.399154 -0.275628  중화1동
# 424  0.003665  0.007088  0.003826  0.001973  0.070661  0.212931  중화2동
#
# [425 rows x 7 columns]

# %%
hos = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\make\서울시 동별 병원_re2.csv', encoding='cp949')
hos.drop('Unnamed: 0', axis=1, inplace=True)

# %%
tot = per.merge(hos, how = 'outer')

# %%
hos
# Out:
#       자치구     동  종합병원  병원  의원  치과병원  치과의원
# 0     송파구  가락1동     0   1   1     0     2
# 1     송파구  가락2동     0   0  20     0    15
# 2     송파구  가락본동     1   4  29     0    25
# 3     구로구  가리봉동     0   0   4     0     4
# 4     금천구   가산동     0   1  25     0    28
# ..    ...   ...   ...  ..  ..   ...   ...
# 420   용산구   효창동     0   0   6     0     4
# 421   용산구   후암동     0   0   6     0     4
# 422  동대문구  휘경1동     0   0  14     0     8
# 423  동대문구  휘경2동     1   0   3     1     2
# 424   동작구   흑석동     1   0  22     0    12
#
# [425 rows x 7 columns]

# %%
tot.isna
# Out:
# <bound method DataFrame.isna of         출생비_k     사망비_k     혼인비_k     이혼비_k      전입_s      전출_s     동  자치구  \
# 0    0.002442  0.004165  0.001724  0.001867 -1.394382 -1.698988  개포1동  강남구
# 1    0.005397  0.002024  0.002166  0.000994  3.622903  0.387324  개포2동  강남구
# 2    0.003849  0.002411  0.003849  0.001734  0.595519 -0.178814  개포4동  강남구
# 3    0.004232  0.003686  0.005097  0.002048  1.003062  1.526013  논현1동  강남구
# 4    0.004864  0.003624  0.004149  0.001907  0.463748  0.793174  논현2동  강남구
# ..        ...       ...       ...       ...       ...       ...   ...  ...
# 422  0.006222  0.004741  0.007901  0.002173  0.611642  0.283458  상봉2동  중랑구
# 423  0.004768  0.006488  0.002475  0.001277  0.212439  0.719442  신내1동  중랑구
# 424  0.006528  0.006874  0.003659  0.001929 -0.642123 -0.438481  신내2동  중랑구
# 425  0.006720  0.006053  0.005027  0.001744 -0.399154 -0.275628  중화1동  중랑구
# 426  0.003665  0.007088  0.003826  0.001973  0.070661  0.212931  중화2동  중랑구
#
#      종합병원  병원   의원  치과병원  치과의원
# ...

# %%
per.sort_values('동', inplace=True)

# %%
#per.to_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\make\컬럼 비율.csv', encoding='cp949')

# %%
per = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\make\컬럼 비율.csv', encoding='cp949')

# %%
per.drop('Unnamed: 0', axis=1, inplace=True)
per
# Out:
#         출생비_k     사망비_k     혼인비_k     이혼비_k      전입_s      전출_s     동
# 0    0.011885  0.002406  0.004192  0.001240  1.372797  1.894676  가락1동
# 1    0.005697  0.002990  0.003399  0.001133  0.480428  0.900888  가락2동
# 2    0.007335  0.003264  0.004685  0.001459  0.343098  0.777787  가락본동
# 3    0.002982  0.008393  0.004970  0.002098 -0.917339 -1.153367  가리봉동
# 4    0.003394  0.003729  0.006997  0.001886  1.761993  1.441380   가산동
# ..        ...       ...       ...       ...       ...       ...   ...
# 420  0.007655  0.003778  0.004971  0.001690 -0.959039 -1.179654   효창동
# 421  0.005010  0.005965  0.004235  0.002147 -0.704394 -0.646856   후암동
# 422  0.005425  0.004711  0.003284  0.001285 -0.160632 -0.593640  휘경1동
# 423  0.003520  0.004141  0.002443  0.001739  0.295838  0.199467  휘경2동
# 424  0.005333  0.005045  0.003481  0.001118  0.434281  0.698925   흑석동
#
# [425 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns
import folium
from matplotlib import rc
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()

# %matplotlib inline

# %%
def elbow(data, length):
    sse = [] # sum of squre error 오차제곱합
    for i in range(1, length):
        kmeans = KMeans(n_clusters=i)
        kmeans.fit(data)
        # SSE 값 저장
        sse.append(kmeans.inertia_)
    plt.plot(range(1, length), sse, 'bo-')
    plt.title("elbow method")
    plt.xlabel("number of clusters")
    plt.ylabel("SSE")
    plt.show()
def visualize_silhouette(cluster_lists, X_features): 

    from sklearn.datasets import make_blobs
    from sklearn.cluster import KMeans
    from sklearn.metrics import silhouette_samples, silhouette_score

    import matplotlib.pyplot as plt
    import matplotlib.cm as cm
    import math

    # 입력값으로 클러스터링 갯수들을 리스트로 받아서, 각 갯수별로 클러스터링을 적용하고 실루엣 개수를 구함
    n_cols = len(cluster_lists)

    # plt.subplots()으로 리스트에 기재된 클러스터링 수만큼의 sub figures를 가지는 axs 생성 
    fig, axs = plt.subplots(figsize=(4*n_cols, 4), nrows=1, ncols=n_cols)

    # 리스트에 기재된 클러스터링 갯수들을 차례로 iteration 수행하면서 실루엣 개수 시각화
    for ind, n_cluster in enumerate(cluster_lists):

        # KMeans 클러스터링 수행하고, 실루엣 스코어와 개별 데이터의 실루엣 값 계산. 
        clusterer = KMeans(n_clusters = n_cluster, max_iter=500, random_state=0)
        cluster_labels = clusterer.fit_predict(X_features)

        sil_avg = silhouette_score(X_features, cluster_labels)
        sil_values = silhouette_samples(X_features, cluster_labels)

        y_lower = 10
        axs[ind].set_title('Number of Cluster : '+ str(n_cluster)+'\n' \
                          'Silhouette Score :' + str(round(sil_avg,3)) )
        axs[ind].set_xlabel("The silhouette coefficient values")
        axs[ind].set_ylabel("Cluster label")
        axs[ind].set_xlim([-0.1, 1])
        axs[ind].set_ylim([0, len(X_features) + (n_cluster + 1) * 10])
        axs[ind].set_yticks([])  # Clear the yaxis labels / ticks
        axs[ind].set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])

        # 클러스터링 갯수별로 fill_betweenx( )형태의 막대 그래프 표현. 
        for i in range(n_cluster):
            ith_cluster_sil_values = sil_values[cluster_labels==i]
            ith_cluster_sil_values.sort()

            size_cluster_i = ith_cluster_sil_values.shape[0]
            y_upper = y_lower + size_cluster_i

            color = cm.nipy_spectral(float(i) / n_cluster)
            axs[ind].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_sil_values, \
                                facecolor=color, edgecolor=color, alpha=0.7)
            axs[ind].text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
            y_lower = y_upper + 10

        axs[ind].axvline(x=sil_avg, color="red", linestyle="--")

# %%
elbow(per.drop(['동','위도','경도'], axis=1),20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 elbow(per.drop(['동','위도','경도'], axis=1),20)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
a = list(range(2,20))
visualize_silhouette(a, per.drop(['동','위도','경도'],axis=1))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23828/2679406533.py in <module>
#       1 a = list(range(2,20))
# ----> 2 visualize_silhouette(a, per.drop(['동','위도','경도'],axis=1))
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
kmeans = KMeans(n_clusters=3, random_state=1234).fit(per.drop(['위도','경도','치과의원','동'],axis=1))
per['cluster'] = kmeans.labels_
per
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 kmeans = KMeans(n_clusters=3, random_state=1234).fit(per.drop(['위도','경도','치과의원','동'],axis=1))
#       2 per['cluster'] = kmeans.labels_
#       3 per
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
per['cluster'].value_counts()
# Out:
# 0    412
# 2     12
# 1      1
# Name: cluster, dtype: int64

# %%
a = minmax.fit_transform(per[['의원','치과의원']])
a = pd.DataFrame(a, columns=per[['의원','치과의원']].columns)
a
# Out:
#            의원      치과의원
# 0    0.002146  0.019608
# 1    0.042918  0.147059
# 2    0.062232  0.245098
# 3    0.008584  0.039216
# 4    0.053648  0.274510
# ..        ...       ...
# 420  0.012876  0.039216
# 421  0.012876  0.039216
# 422  0.030043  0.078431
# 423  0.006438  0.019608
# 424  0.047210  0.117647
#
# [425 rows x 2 columns]

# %%
per[['의원','치과의원']] = a

# %%
per
# Out:
#         출생비_k     사망비_k     혼인비_k     이혼비_k      전입_s      전출_s        의원  \
# 0    0.011885  0.002406  0.004192  0.001240  1.372797  1.894676  0.002146
# 1    0.005697  0.002990  0.003399  0.001133  0.480428  0.900888  0.042918
# 2    0.007335  0.003264  0.004685  0.001459  0.343098  0.777787  0.062232
# 3    0.002982  0.008393  0.004970  0.002098 -0.917339 -1.153367  0.008584
# 4    0.003394  0.003729  0.006997  0.001886  1.761993  1.441380  0.053648
# ..        ...       ...       ...       ...       ...       ...       ...
# 420  0.007655  0.003778  0.004971  0.001690 -0.959039 -1.179654  0.012876
# 421  0.005010  0.005965  0.004235  0.002147 -0.704394 -0.646856  0.012876
# 422  0.005425  0.004711  0.003284  0.001285 -0.160632 -0.593640  0.030043
# 423  0.003520  0.004141  0.002443  0.001739  0.295838  0.199467  0.006438
# 424  0.005333  0.005045  0.003481  0.001118  0.434281  0.698925  0.047210
#
#          치과의원     동         위도          경도  cluster
# ...

# %% [markdown]
# ## 치과

# %%
kmeans = KMeans(n_clusters=3, random_state=1234).fit(per.drop(['의원','동'],axis=1))
per['cluster'] = kmeans.labels_
per['cluster'].value_counts()
# Out:
# 0    198
# 2    162
# 1     65
# Name: cluster, dtype: int64

# %%
m_2 = folium.Map(
    location = (sum(per['위도'])/len(per['위도']), sum(per['경도'])/len(per['경도']) ),
    tiles='cartodbdark_matter',
    zoom_start = 11)
for i in range(per.shape[0]):
    
    if per['cluster'][i] == 0:
        color = 'blue'
    elif per['cluster'][i] == 1:
        color = 'red'
    elif per['cluster'][i] == 2:
        color = 'green'
    else :
        pass
    c = per.iat[i,9],per.iat[i,10]
    folium.Circle(c, popup=per['cluster'][i], color = color).add_to(m_2)
m_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
per.groupby(by='cluster').agg('mean')
# Out:
#             출생비_k     사망비_k     혼인비_k     이혼비_k      전입_s      전출_s        의원  \
# cluster
# 0        0.005055  0.004786  0.003903  0.001561  0.097784  0.201063  0.042593
# 1        0.005566  0.004485  0.004980  0.001642  1.732542  1.652034  0.068703
# 2        0.004723  0.005653  0.004655  0.001784 -0.814669 -0.908597  0.028732
#
#              치과의원         위도          경도
# cluster
# 0        0.116310  37.551184  126.990577
# 1        0.176471  37.529615  126.999120
# 2        0.076918  37.555705  126.995257

# %% [markdown]
# ## 의원

# %%
kmeans = KMeans(n_clusters=3, random_state=1234).fit(per.drop(['치과의원','동'],axis=1))
per['cluster'] = kmeans.labels_
per['cluster'].value_counts()
# Out:
# 0    198
# 1    162
# 2     65
# Name: cluster, dtype: int64

# %%
m_1 = folium.Map(
    location = (sum(per['위도'])/len(per['위도']), sum(per['경도'])/len(per['경도']) ),
    tiles='cartodbdark_matter',
    zoom_start = 11)
for i in range(per.shape[0]):
    
    if per['cluster'][i] == 0:
        color = 'blue'
    elif per['cluster'][i] == 2:
        color = 'red'
    elif per['cluster'][i] == 1:
        color = 'green'
    else :
        pass
    c = per.iat[i,9],per.iat[i,10]
    folium.Circle(c, popup=per['cluster'][i], color = color).add_to(m_1)
m_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
per.groupby(by='cluster').agg('mean')
# Out:
#             출생비_k     사망비_k     혼인비_k     이혼비_k      전입_s      전출_s        의원  \
# cluster
# 0        0.005055  0.004786  0.003903  0.001561  0.097784  0.201063  0.042593
# 1        0.004723  0.005653  0.004655  0.001784 -0.814669 -0.908597  0.028732
# 2        0.005566  0.004485  0.004980  0.001642  1.732542  1.652034  0.068703
#
#              치과의원         위도          경도
# cluster
# 0        0.116310  37.551184  126.990577
# 1        0.076918  37.555705  126.995257
# 2        0.176471  37.529615  126.999120

# %%
m_1.save('비율+의원.html')
m_2.save('비율+치과의원.html')

# %%
per[per['cluster'] == 2]['동']
# Out:
# 0      가락1동
# 4       가산동
# 5      가양1동
# 11      강일동
# 16     개포2동
#        ...
# 385     청룡동
# 402     행운동
# 409    화곡1동
# 415    화곡본동
# 416     화양동
# Name: 동, Length: 65, dtype: object

# %%
per
# Out:
#         출생비_k     사망비_k     혼인비_k     이혼비_k      전입_s      전출_s        의원  \
# 0    0.011885  0.002406  0.004192  0.001240  1.372797  1.894676  0.002146
# 1    0.005697  0.002990  0.003399  0.001133  0.480428  0.900888  0.042918
# 2    0.007335  0.003264  0.004685  0.001459  0.343098  0.777787  0.062232
# 3    0.002982  0.008393  0.004970  0.002098 -0.917339 -1.153367  0.008584
# 4    0.003394  0.003729  0.006997  0.001886  1.761993  1.441380  0.053648
# ..        ...       ...       ...       ...       ...       ...       ...
# 420  0.007655  0.003778  0.004971  0.001690 -0.959039 -1.179654  0.012876
# 421  0.005010  0.005965  0.004235  0.002147 -0.704394 -0.646856  0.012876
# 422  0.005425  0.004711  0.003284  0.001285 -0.160632 -0.593640  0.030043
# 423  0.003520  0.004141  0.002443  0.001739  0.295838  0.199467  0.006438
# 424  0.005333  0.005045  0.003481  0.001118  0.434281  0.698925  0.047210
#
#          치과의원     동         위도          경도  cluster
# ...

# %%
per[per['cluster'] == 1]['동']
# Out:
# 3      가리봉동
# 6      가양2동
# 7      가양3동
# 8       가회동
# 14     개봉3동
#        ...
# 418     회기동
# 419     회현동
# 420     효창동
# 421     후암동
# 422    휘경1동
# Name: 동, Length: 162, dtype: object

# %%
per[per['cluster'] == 0]['동']
# Out:
# 1      가락2동
# 2      가락본동
# 9      갈현1동
# 10     갈현2동
# 12     개봉1동
#        ...
# 411    화곡3동
# 413    화곡6동
# 414    화곡8동
# 423    휘경2동
# 424     흑석동
# Name: 동, Length: 198, dtype: object

# %%
m_1.save('의원.html')
m_2.save('치과의원.html')

# %%
per.to_csv('확인용.csv', encoding='cp949')
