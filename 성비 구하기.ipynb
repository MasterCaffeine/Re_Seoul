# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 동작구가 빠져서 엑셀로 편집함

# %%
aa = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_강동구.csv', encoding = 'cp949')
bb = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_송파구.csv', encoding = 'cp949')
cc = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_강남구.csv', encoding = 'cp949')
dd = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_서초구.csv', encoding = 'cp949')
ee = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_관악구.csv', encoding = 'cp949')
ff = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_동작구.csv', encoding = 'cp949')
gg = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_영등포구.csv', encoding = 'cp949')
hh = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_금천구.csv', encoding = 'cp949')
ii = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_구로구.csv', encoding = 'cp949')
jj = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_강서구.csv', encoding = 'cp949')
kk = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_양천구.csv', encoding = 'cp949')
ll = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_마포구.csv', encoding = 'cp949')
mm = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_서대문구.csv', encoding = 'cp949')
nn = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_은평구.csv', encoding = 'cp949')
oo = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_노원구.csv', encoding = 'cp949')
pp = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_도봉구.csv', encoding = 'cp949')
qq = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_강북구.csv', encoding = 'cp949')
rr =pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_성북구.csv', encoding = 'cp949')
xx =pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_중랑구.csv', encoding = 'cp949')
yy =pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_동대문구.csv', encoding = 'cp949')
zz =pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_성동구.csv', encoding = 'cp949')
aaa =pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_용산.csv', encoding = 'cp949')
bbb = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_중구.csv', encoding = 'cp949')
ccc = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_종로구.csv', encoding = 'cp949')
ddd = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\202204_202204_연령별인구현황_월간_광진구.csv', encoding = 'cp949')

# %%
aa.drop(0, axis=0, inplace=True)#
bb.drop(0, axis=0, inplace=True)#
cc.drop(0, axis=0, inplace=True)#
dd.drop(0, axis=0, inplace=True)#
ee.drop(0, axis=0, inplace=True)#
ff.drop(0, axis=0, inplace=True)#
gg.drop(0, axis=0, inplace=True)#
hh.drop(0, axis=0, inplace=True)#
ii.drop(0, axis=0, inplace=True)#
jj.drop(0, axis=0, inplace=True)#
kk.drop(0, axis=0, inplace=True)#
ll.drop(0, axis=0, inplace=True)#
mm.drop(0, axis=0, inplace=True)#
nn.drop(0, axis=0, inplace=True)#
oo.drop(0, axis=0, inplace=True)#
pp.drop(0, axis=0, inplace=True)#
qq.drop(0, axis=0, inplace=True)#
rr.drop(0, axis=0, inplace=True)#
xx.drop(0, axis=0, inplace=True)#
yy.drop(0, axis=0, inplace=True)#
zz.drop(0, axis=0, inplace=True)#
aaa.drop(0, axis=0, inplace=True)#
bbb.drop(0, axis=0, inplace=True)#
ccc.drop(0, axis=0, inplace=True)#
ddd.drop(0, axis=0, inplace=True)#

# %%
pop = aa.append([bb,cc,dd,ee,ff,gg,hh,ii,jj,kk,ll,mm,nn,oo,pp,qq,rr,xx,yy,zz,aaa,bbb,ccc,ddd])
# Out:
# C:\Users\2106-017\AppData\Local\Temp\ipykernel_732132\2693878039.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   pop = aa.append([bb,cc,dd,ee,ff,gg,hh,ii,jj,kk,ll,mm,nn,oo,pp,qq,rr,xx,yy,zz,aaa,bbb,ccc,ddd])

# %%
pop
# Out:
#                            행정구역 2022년04월_계_총인구수 2022년04월_계_연령구간인구수  \
# 1     서울특별시 강동구 강일동(1174051500)          32,774             32,774
# 2   서울특별시 강동구 상일제1동(1174052500)          38,805             38,805
# 3   서울특별시 강동구 상일제2동(1174052600)          10,709             10,709
# 4   서울특별시 강동구 명일제1동(1174053000)          25,757             25,757
# 5   서울특별시 강동구 명일제2동(1174054000)          17,453             17,453
# ..                          ...             ...                ...
# 11  서울특별시 광진구 자양제3동(1121584000)          27,902             27,902
# 12  서울특별시 광진구 자양제4동(1121584700)          17,992             17,992
# 13  서울특별시 광진구 구의제1동(1121585000)          23,006             23,006
# 14  서울특별시 광진구 구의제2동(1121586000)          26,361             26,361
# 15  서울특별시 광진구 구의제3동(1121587000)          28,515             28,515
#
#    2022년04월_계_0~9세 2022년04월_계_10~19세 2022년04월_계_20~29세 2022년04월_계_30~39세  \
# 1            2,987             3,579             3,574             4,493
# ...

# %%
#pop.to_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\people.csv', encoding='cp949')

# %%
pop = pd.read_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\인구\people.csv', encoding='cp949')
pop.drop('Unnamed: 0', axis=1, inplace=True)

# %%
pop.drop(['Unnamed: 4', 'Unnamed: 5'], axis=1, inplace=True)

# %%
splitt = pop['행정구역'].str.split(expand=True)

# %%
splitt
# Out:
#          0    1                   2
# 0    서울특별시  강동구     강일동(1174051500)
# 1    서울특별시  강동구     상일동(1174052500)
# 2    서울특별시  강동구   명일제1동(1174053000)
# 3    서울특별시  강동구   명일제2동(1174054000)
# 4    서울특별시  강동구   고덕제1동(1174055000)
# ..     ...  ...                 ...
# 420  서울특별시  동작구   사당제4동(1159065000)
# 421  서울특별시  동작구   사당제5동(1159065100)
# 422  서울특별시  동작구     대방동(1159066000)
# 423  서울특별시  동작구  신대방제1동(1159067000)
# 424  서울특별시  동작구  신대방제2동(1159068000)
#
# [425 rows x 3 columns]

# %%
import re

# %%
splitt[2]
# Out:
# 0         강일동(1174051500)
# 1         상일동(1174052500)
# 2       명일제1동(1174053000)
# 3       명일제2동(1174054000)
# 4       고덕제1동(1174055000)
#               ...
# 420     사당제4동(1159065000)
# 421     사당제5동(1159065100)
# 422       대방동(1159066000)
# 423    신대방제1동(1159067000)
# 424    신대방제2동(1159068000)
# Name: 2, Length: 425, dtype: object

# %%
splitt[2][0]
# Out:
# '강일동(1174051500)'

# %%
re.sub('[0-9]','', splitt[2][0])
# Out:
# '강일동()'

# %%
splitt[2] = splitt[2].apply(lambda x: re.sub('\(.*\)|\s-\s.*','',x))
splitt[2]
# Out:
# 0         강일동
# 1         상일동
# 2       명일제1동
# 3       명일제2동
# 4       고덕제1동
#         ...
# 420     사당제4동
# 421     사당제5동
# 422       대방동
# 423    신대방제1동
# 424    신대방제2동
# Name: 2, Length: 425, dtype: object

# %%
splitt
# Out:
#          0    1       2
# 0    서울특별시  강동구     강일동
# 1    서울특별시  강동구     상일동
# 2    서울특별시  강동구   명일제1동
# 3    서울특별시  강동구   명일제2동
# 4    서울특별시  강동구   고덕제1동
# ..     ...  ...     ...
# 420  서울특별시  동작구   사당제4동
# 421  서울특별시  동작구   사당제5동
# 422  서울특별시  동작구     대방동
# 423  서울특별시  동작구  신대방제1동
# 424  서울특별시  동작구  신대방제2동
#
# [425 rows x 3 columns]

# %%
pop['자치구'] = splitt[1]
pop['동'] = splitt[2]

# %%
pop.drop('행정구역', axis=1, inplace=True)
# pop.to_csv('서울동별성비.csv', encoding='cp949')

# %%
type(pop['2022년04월_남_총인구수'][0])
# Out:
# str

# %%
pop
# Out:
#     2022년04월_남_총인구수 2022년04월_여_총인구수  자치구       동
# 0            15,732          17,042  강동구     강일동
# 1             24139           25375  강동구     상일동
# 2            12,536          13,221  강동구   명일제1동
# 3             8,535           8,918  강동구   명일제2동
# 4            12,135          11,737  강동구   고덕제1동
# ..              ...             ...  ...     ...
# 420           6,762           7,415  동작구   사당제4동
# 421           6,916           7,508  동작구   사당제5동
# 422          17,891          19,882  동작구     대방동
# 423          11,023          11,968  동작구  신대방제1동
# 424          10,538          11,504  동작구  신대방제2동
#
# [425 rows x 4 columns]

# %%
pop = pd.read_csv('서울동별성비.csv', encoding='cp949')
pop.drop('Unnamed: 0', axis=1, inplace=True)
pop['2022년04월_남_총인구수'] = pop['2022년04월_남_총인구수'].apply(lambda x: re.sub(',','',x))
pop['2022년04월_여_총인구수'] = pop['2022년04월_여_총인구수'].apply(lambda x: re.sub(',','',x))

# %%
pop['2022년04월_남_총인구수'] = pop['2022년04월_남_총인구수'].apply(lambda x: int(x))
pop['2022년04월_여_총인구수'] = pop['2022년04월_여_총인구수'].apply(lambda x: int(x))

# %%
pop
# Out:
#      2022년04월_남_총인구수  2022년04월_여_총인구수  자치구       동
# 0              15732            17042  강동구     강일동
# 1              24139            25375  강동구     상일동
# 2              12536            13221  강동구   명일제1동
# 3               8535             8918  강동구   명일제2동
# 4              12135            11737  강동구   고덕제1동
# ..               ...              ...  ...     ...
# 420             6762             7415  동작구   사당제4동
# 421             6916             7508  동작구   사당제5동
# 422            17891            19882  동작구     대방동
# 423            11023            11968  동작구  신대방제1동
# 424            10538            11504  동작구  신대방제2동
#
# [425 rows x 4 columns]

# %%
pop = pd.read_excel(r'C:\Users\2106-017\Downloads\팝.xlsx')
pop.drop('Unnamed: 0', axis=1, inplace=True)
pop.iloc[317,3] = '제기동'

# %%
pop
# Out:
#      2022년04월_남_총인구수  2022년04월_여_총인구수  자치구      동
# 0            15732.0          17042.0  강동구    강일동
# 1            24139.0          25375.0  강동구    상일동
# 2            12536.0          13221.0  강동구   명일1동
# 3             8535.0           8918.0  강동구   명일2동
# 4            12135.0          11737.0  강동구   고덕1동
# ..               ...              ...  ...    ...
# 420           6762.0           7415.0  동작구   사당4동
# 421           6916.0           7508.0  동작구   사당5동
# 422          17891.0          19882.0  동작구    대방동
# 423          11023.0          11968.0  동작구  신대방1동
# 424          10538.0          11504.0  동작구  신대방2동
#
# [425 rows x 4 columns]

# %%
add = add.merge(pop, how='outer')
add
# Out:
#         동  자치구   출생   사망    전입    전출   혼인  이혼    주민센터 이름  \
# 0    개포1동  강남구   17   29   829   937   12  13  개포1동 주민센터
# 1    개포2동  강남구  152   57  9853  4191   61  28  개포2동 주민센터
# 2    개포4동  강남구   91   57  4408  3308   91  41  개포4동 주민센터
# 3    논현1동  강남구   93   81  5141  5967  112  45  논현1동 주민센터
# 4    논현2동  강남구  102   76  4171  4824   87  40  논현2동 주민센터
# ..    ...  ...  ...  ...   ...   ...  ...  ..        ...
# 420  상봉2동  중랑구  126   96  4437  4029  160  44  상봉2동 주민센터
# 421  신내1동  중랑구  183  249  3719  4709   95  49  신내1동 주민센터
# 422  신내2동  중랑구  132  139  2182  2903   74  39  신내2동 주민센터
# 423  중화1동  중랑구  131  118  2619  3157   98  34  중화1동 주민센터
# 424  중화2동  중랑구   91  176  3464  3919   95  49  중화2동 주민센터
#
#                     주민센터 주소         위도          경도  2022년04월_남_총인구수  \
# 0      서울특별시 강남구 개포로 310-17  37.481054  127.053708           3384.0
# 1         서울특별시 강남구 개포로 511  37.489774  127.069120          13661.0
# 2       서울특별시 강남구 개포로38길 12  37.478999  127.051657          11422.0
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns
from matplotlib import rc
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()

# %matplotlib inline

plt.rc("font", family = "Malgun Gothic")
sns.set(font="Malgun Gothic", 
rc={"axes.unicode_minus":False}, style='darkgrid')

# %%
def elbow(data, length):
    sse = [] # sum of squre error 오차제곱합
    for i in range(1, length):
        kmeans = KMeans(n_clusters=i)
        kmeans.fit(data)
        # SSE 값 저장
        sse.append(kmeans.inertia_)
    plt.plot(range(1, length), sse, 'bo-')
    plt.title("elbow method")
    plt.xlabel("number of clusters")
    plt.ylabel("SSE")
    plt.show()

# %%
def visualize_silhouette(cluster_lists, X_features): 

    from sklearn.datasets import make_blobs
    from sklearn.cluster import KMeans
    from sklearn.metrics import silhouette_samples, silhouette_score

    import matplotlib.pyplot as plt
    import matplotlib.cm as cm
    import math

    # 입력값으로 클러스터링 갯수들을 리스트로 받아서, 각 갯수별로 클러스터링을 적용하고 실루엣 개수를 구함
    n_cols = len(cluster_lists)

    # plt.subplots()으로 리스트에 기재된 클러스터링 수만큼의 sub figures를 가지는 axs 생성 
    fig, axs = plt.subplots(figsize=(4*n_cols, 4), nrows=1, ncols=n_cols)

    # 리스트에 기재된 클러스터링 갯수들을 차례로 iteration 수행하면서 실루엣 개수 시각화
    for ind, n_cluster in enumerate(cluster_lists):

        # KMeans 클러스터링 수행하고, 실루엣 스코어와 개별 데이터의 실루엣 값 계산. 
        clusterer = KMeans(n_clusters = n_cluster, max_iter=500, random_state=0)
        cluster_labels = clusterer.fit_predict(X_features)

        sil_avg = silhouette_score(X_features, cluster_labels)
        sil_values = silhouette_samples(X_features, cluster_labels)

        y_lower = 10
        axs[ind].set_title('Number of Cluster : '+ str(n_cluster)+'\n' \
                          'Silhouette Score :' + str(round(sil_avg,3)) )
        axs[ind].set_xlabel("The silhouette coefficient values")
        axs[ind].set_ylabel("Cluster label")
        axs[ind].set_xlim([-0.1, 1])
        axs[ind].set_ylim([0, len(X_features) + (n_cluster + 1) * 10])
        axs[ind].set_yticks([])  # Clear the yaxis labels / ticks
        axs[ind].set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])

        # 클러스터링 갯수별로 fill_betweenx( )형태의 막대 그래프 표현. 
        for i in range(n_cluster):
            ith_cluster_sil_values = sil_values[cluster_labels==i]
            ith_cluster_sil_values.sort()

            size_cluster_i = ith_cluster_sil_values.shape[0]
            y_upper = y_lower + size_cluster_i

            color = cm.nipy_spectral(float(i) / n_cluster)
            axs[ind].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_sil_values, \
                                facecolor=color, edgecolor=color, alpha=0.7)
            axs[ind].text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
            y_lower = y_upper + 10

        axs[ind].axvline(x=sil_avg, color="red", linestyle="--")

# %%
col = ['출생','사망','전입','전출','혼인','이혼','2022년04월_남_총인구수','2022년04월_여_총인구수']
add_kmean = add[col]
add_kmean
# Out:
#       출생   사망    전입    전출   혼인  이혼  2022년04월_남_총인구수  2022년04월_여_총인구수
# 0     17   29   829   937   12  13           3384.0           3585.0
# 1    152   57  9853  4191   61  28          13661.0          14477.0
# 2     91   57  4408  3308   91  41          11422.0          12185.0
# 3     93   81  5141  5967  112  45          10361.0          11620.0
# 4    102   76  4171  4824   87  40           9791.0          11160.0
# ..   ...  ...   ...   ...  ...  ..              ...              ...
# 420  126   96  4437  4029  160  44           9770.0          10463.0
# 421  183  249  3719  4709   95  49          18542.0          19768.0
# 422  132  139  2182  2903   74  39           9625.0          10590.0
# 423  131  118  2619  3157   98  34           9556.0           9897.0
# 424   91  176  3464  3919   95  49          12748.0          12073.0
#
# [425 rows x 8 columns]

# %%
elbow(add_kmean,30)
# Out:
# C:\Users\2106-017\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
a = list(range(2,40))
visualize_silhouette(a, add_kmean)

# %%
std_data = std.fit_transform(add_kmean)
std_data = pd.DataFrame(std_data, columns=add_kmean.columns)
kmeans = KMeans(n_clusters=3, random_state=1234).fit(std_data)
add_kmean['cluster'] = kmeans.labels_
add['cluster'] = add_kmean['cluster']
# Out:
# C:\Users\2106-017\AppData\Local\Temp\ipykernel_7960\171641.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   add_kmean['cluster'] = kmeans.labels_

# %%
add
# Out:
#         동  자치구   출생   사망    전입    전출   혼인  이혼    주민센터 이름  \
# 0    개포1동  강남구   17   29   829   937   12  13  개포1동 주민센터
# 1    개포2동  강남구  152   57  9853  4191   61  28  개포2동 주민센터
# 2    개포4동  강남구   91   57  4408  3308   91  41  개포4동 주민센터
# 3    논현1동  강남구   93   81  5141  5967  112  45  논현1동 주민센터
# 4    논현2동  강남구  102   76  4171  4824   87  40  논현2동 주민센터
# ..    ...  ...  ...  ...   ...   ...  ...  ..        ...
# 420  상봉2동  중랑구  126   96  4437  4029  160  44  상봉2동 주민센터
# 421  신내1동  중랑구  183  249  3719  4709   95  49  신내1동 주민센터
# 422  신내2동  중랑구  132  139  2182  2903   74  39  신내2동 주민센터
# 423  중화1동  중랑구  131  118  2619  3157   98  34  중화1동 주민센터
# 424  중화2동  중랑구   91  176  3464  3919   95  49  중화2동 주민센터
#
#                     주민센터 주소         위도          경도  2022년04월_남_총인구수  \
# 0      서울특별시 강남구 개포로 310-17  37.481054  127.053708           3384.0
# 1         서울특별시 강남구 개포로 511  37.489774  127.069120          13661.0
# 2       서울특별시 강남구 개포로38길 12  37.478999  127.051657          11422.0
# ...

# %%
import folium

# %%
m_1 = folium.Map(
    location = (sum(add['위도'])/len(add['위도']), sum(add['경도'])/len(add['경도']) ),
    tiles='cartodbdark_matter',
    zoom_start = 11)
for i in range(add.shape[0]):
    
    if add['cluster'][i] == 0:
        color = 'blue'
    elif add['cluster'][i] == 1:
        color = 'red'
    elif add['cluster'][i] == 2:
        color = 'green'
    else :
        pass
    c = add.iat[i,10],add.iat[i,11]
    title = add.iat[i,0]
    folium.Circle(c, popup=add['cluster'][i], color = color, tooltip=title).add_to(m_1)
m_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
