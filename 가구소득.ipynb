# %%
import pandas as pd
import numpy as np
import re

# %%
a = pd.read_csv(r'C:\Users\2106-017\Documents\카카오톡 받은 파일\가구_특성정보_(+소득정보)_211203.csv')
a
# Out:
#               adstrd_nm   adstrd_cd legaldong_nm  legaldong_cd  tot_po  \
# 0       서울특별시 종로구 청운효자동  1111051500          청운동    1111010100   11680
# 1       서울특별시 종로구 청운효자동  1111051500          신교동    1111010200   11680
# 2       서울특별시 종로구 청운효자동  1111051500          궁정동    1111010300   11680
# 3       서울특별시 종로구 청운효자동  1111051500          효자동    1111010400   11680
# 4       서울특별시 종로구 청운효자동  1111051500          창성동    1111010500   11680
# ...                 ...         ...          ...           ...     ...
# 19571  제주특별자치도 서귀포시 중문동  5013061000          대포동    5013011400   11348
# 19572  제주특별자치도 서귀포시 중문동  5013061000          하원동    5013011800   11348
# 19573  제주특별자치도 서귀포시 예래동  5013062000          색달동    5013011900    3846
# 19574  제주특별자치도 서귀포시 예래동  5013062000          상예동    5013012000    3846
# 19575  제주특별자치도 서귀포시 예래동  5013062000          하예동    5013012100    3846
#
#        tot_hshld_co  hshld_per_po  ave_income_amt
# 0              4715          2.48         9049.02
# ...

# %%
a.drop(['adstrd_cd', 'legaldong_cd'], axis=1, inplace=True)
a
# Out:
#               adstrd_nm legaldong_nm  tot_po  tot_hshld_co  hshld_per_po  \
# 0       서울특별시 종로구 청운효자동          청운동   11680          4715          2.48
# 1       서울특별시 종로구 청운효자동          신교동   11680          4715          2.48
# 2       서울특별시 종로구 청운효자동          궁정동   11680          4715          2.48
# 3       서울특별시 종로구 청운효자동          효자동   11680          4715          2.48
# 4       서울특별시 종로구 청운효자동          창성동   11680          4715          2.48
# ...                 ...          ...     ...           ...           ...
# 19571  제주특별자치도 서귀포시 중문동          대포동   11348          4852          2.34
# 19572  제주특별자치도 서귀포시 중문동          하원동   11348          4852          2.34
# 19573  제주특별자치도 서귀포시 예래동          색달동    3846          1692          2.27
# 19574  제주특별자치도 서귀포시 예래동          상예동    3846          1692          2.27
# 19575  제주특별자치도 서귀포시 예래동          하예동    3846          1692          2.27
#
#        ave_income_amt
# 0             9049.02
# 1             5544.59
# ...

# %%
re.search('^서울특별시', a['adstrd_nm'][0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20172/681946755.py in <module>
# ----> 1 re.search('^서울특별시', a['adstrd_nm'][0])
#
# TypeError: list indices must be integers or slices, not str

# %%
a
# Out:
#               adstrd_nm legaldong_nm  tot_po  tot_hshld_co  hshld_per_po  \
# 0       서울특별시 종로구 청운효자동          청운동   11680          4715          2.48
# 1       서울특별시 종로구 청운효자동          신교동   11680          4715          2.48
# 2       서울특별시 종로구 청운효자동          궁정동   11680          4715          2.48
# 3       서울특별시 종로구 청운효자동          효자동   11680          4715          2.48
# 4       서울특별시 종로구 청운효자동          창성동   11680          4715          2.48
# ...                 ...          ...     ...           ...           ...
# 19571  제주특별자치도 서귀포시 중문동          대포동   11348          4852          2.34
# 19572  제주특별자치도 서귀포시 중문동          하원동   11348          4852          2.34
# 19573  제주특별자치도 서귀포시 예래동          색달동    3846          1692          2.27
# 19574  제주특별자치도 서귀포시 예래동          상예동    3846          1692          2.27
# 19575  제주특별자치도 서귀포시 예래동          하예동    3846          1692          2.27
#
#        ave_income_amt
# 0             9049.02
# 1             5544.59
# ...

# %%
cure = []
for i in range(len(a['adstrd_nm'])):
    k__ = a['adstrd_nm'][i].split(' ')
    if k__[0] == '서울특별시':
        cure.append(k__)
    elif k__[0] != '서울특별시':
        pass
    else:
        continue
cure
# Out:
# [['서울특별시', '종로구', '청운효자동'],
#  ['서울특별시', '종로구', '청운효자동'],
#  ['서울특별시', '종로구', '청운효자동'],
#  ['서울특별시', '종로구', '청운효자동'],
#  ['서울특별시', '종로구', '청운효자동'],
#  ['서울특별시', '종로구', '청운효자동'],
#  ['서울특별시', '종로구', '청운효자동'],
#  ['서울특별시', '종로구', '청운효자동'],
#  ['서울특별시', '종로구', '청운효자동'],
#  ['서울특별시', '종로구', '청운효자동'],
#  ['서울특별시', '종로구', '사직동'],
#  ['서울특별시', '종로구', '사직동'],
#  ['서울특별시', '종로구', '사직동'],
#  ['서울특별시', '종로구', '사직동'],
#  ['서울특별시', '종로구', '사직동'],
#  ['서울특별시', '종로구', '사직동'],
#  ['서울특별시', '종로구', '사직동'],
#  ['서울특별시', '종로구', '사직동'],
#  ['서울특별시', '종로구', '사직동'],
#  ['서울특별시', '종로구', '사직동'],
#  ['서울특별시', '종로구', '사직동'],
#  ['서울특별시', '종로구', '사직동'],
#  ['서울특별시', '종로구', '삼청동'],
#  ['서울특별시', '종로구', '삼청동'],
#  ['서울특별시', '종로구', '삼청동'],
#  ['서울특별시', '종로구', '삼청동'],
#  ['서울특별시', '종로구', '삼청동'],
#  ['서울특별시', '종로구', '삼청동'],
#  ['서울특별시', '종로구', '삼청동'],
#  ['서울특별시', '종로구', '부암동'],
#  ['서울특별시', '종로구', '부암동'],
#  ['서울특별시', '종로구', '부암동'],
#  ['서울특별시', '종로구', '평창동'],
#  ['서울특별시', '종로구', '평창동'],
#  ['서울특별시', '종로구', '무악동'],
# ...

# %%
len(cure)
# Out:
# 728

# %%
a['adstrd_nm'].str.contains( '서울특별시')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20172/531441611.py in <module>
# ----> 1 a['adstrd_nm'].str.contains( '서울특별시')
#
# TypeError: list indices must be integers or slices, not str

# %%
b = a[ a['adstrd_nm'].str.contains( '서울특별시') ]
b
# Out:
#            adstrd_nm legaldong_nm  tot_po  tot_hshld_co  hshld_per_po  \
# 0    서울특별시 종로구 청운효자동          청운동   11680          4715          2.48
# 1    서울특별시 종로구 청운효자동          신교동   11680          4715          2.48
# 2    서울특별시 종로구 청운효자동          궁정동   11680          4715          2.48
# 3    서울특별시 종로구 청운효자동          효자동   11680          4715          2.48
# 4    서울특별시 종로구 청운효자동          창성동   11680          4715          2.48
# ..               ...          ...     ...           ...           ...
# 725   서울특별시 강동구 성내2동          성내동   24026         11954          2.01
# 726   서울특별시 강동구 성내3동          성내동   22682          9716          2.33
# 727     서울특별시 강동구 길동           길동   44791         19714          2.27
# 728   서울특별시 강동구 둔촌1동          둔촌동      36            14          2.57
# 729   서울특별시 강동구 둔촌2동          둔촌동   26071         10041          2.60
#
#      ave_income_amt
# 0           9049.02
# 1           5544.59
# 2           7078.69
# 3           5403.79
# ...

# %%
b.describe
# Out:
# <bound method NDFrame.describe of            adstrd_nm legaldong_nm  tot_po  tot_hshld_co  hshld_per_po  \
# 0    서울특별시 종로구 청운효자동          청운동   11680          4715          2.48
# 1    서울특별시 종로구 청운효자동          신교동   11680          4715          2.48
# 2    서울특별시 종로구 청운효자동          궁정동   11680          4715          2.48
# 3    서울특별시 종로구 청운효자동          효자동   11680          4715          2.48
# 4    서울특별시 종로구 청운효자동          창성동   11680          4715          2.48
# ..               ...          ...     ...           ...           ...
# 725   서울특별시 강동구 성내2동          성내동   24026         11954          2.01
# 726   서울특별시 강동구 성내3동          성내동   22682          9716          2.33
# 727     서울특별시 강동구 길동           길동   44791         19714          2.27
# 728   서울특별시 강동구 둔촌1동          둔촌동      36            14          2.57
# 729   서울특별시 강동구 둔촌2동          둔촌동   26071         10041          2.60
#
#      ave_income_amt
# 0           9049.02
# 1           5544.59
# 2           7078.69
# ...

# %%
b.to_csv(r'C:\Users\2106-017\Desktop\서울시_행정구역\make\소득정보.csv', encoding='cp949')

# %%
c = b.groupby(by = 'adstrd_nm').agg('mean')
c
# Out:
#                  tot_po  tot_hshld_co  hshld_per_po  ave_income_amt
# adstrd_nm
# 서울특별시 강남구 개포1동   6053.0        2334.0          2.59        8492.840
# 서울특별시 강남구 개포2동  21067.0        7463.0          2.82        9551.995
# 서울특별시 강남구 개포4동  19458.0        7890.0          2.47        8492.840
# 서울특별시 강남구 논현1동  22095.0       12828.0          1.72       13078.130
# 서울특별시 강남구 논현2동  20669.0       10294.0          2.01       13078.130
# ...                 ...           ...           ...             ...
# 서울특별시 중랑구 상봉2동  19511.0       10496.0          1.86        3987.760
# 서울특별시 중랑구 신내1동  38747.0       13693.0          2.83        3837.790
# 서울특별시 중랑구 신내2동  20706.0        8487.0          2.44        3837.790
# 서울특별시 중랑구 중화1동  19653.0        8196.0          2.40        3967.030
# 서울특별시 중랑구 중화2동  25395.0       12539.0          2.03        3967.030
#
# [423 rows x 4 columns]

# %%
c.to_excel(r'C:\Users\2106-017\Desktop\서울시_행정구역\make\동별소득.xlsx')

# %%
re.sub('서울특별시\(|\)', "", c['adstrd_nm'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'adstrd_nm'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# # 병원 수, 추가

# %%
tot = pd.read_excel(r'C:\Users\2106-017\Desktop\서울시_행정구역\make\all.xlsx')
hos = pd.read_excel(r'C:\Users\2106-017\Desktop\서울시_행정구역\make\병원 수(항동추가).xlsx')

# %%
tot.drop('Unnamed: 0', axis=1, inplace=True)

# %%
tot
# Out:
#      자치구     동   출생   사망    전입    전출   혼인  이혼
# 0    강남구  개포1동   17   29   829   937   12  13
# 1    강남구  개포2동  152   57  9853  4191   61  28
# 2    강남구  개포4동   91   57  4408  3308   91  41
# 3    강남구  논현1동   93   81  5141  5967  112  45
# 4    강남구  논현2동  102   76  4171  4824   87  40
# ..   ...   ...  ...  ...   ...   ...  ...  ..
# 420  중랑구  상봉2동  126   96  4437  4029  160  44
# 421  중랑구  신내1동  183  249  3719  4709   95  49
# 422  중랑구  신내2동  132  139  2182  2903   74  39
# 423  중랑구  중화1동  131  118  2619  3157   98  34
# 424  중랑구  중화2동   91  176  3464  3919   95  49
#
# [425 rows x 8 columns]

# %%
hos.drop(['Unnamed: 0', '병상수'], axis=1, inplace=True)

# %%
hos
# Out:
#      자치구     동  병원수
# 0    강남구  개포1동    8
# 1    강남구  개포2동   26
# 2    강남구  개포4동   33
# 3    강남구  논현1동  250
# 4    강남구  논현2동  149
# ..   ...   ...  ...
# 420  중랑구  상봉2동   38
# 421  중랑구  신내1동   39
# 422  중랑구  신내2동   25
# 423  중랑구  중화1동   20
# 424  중랑구  중화2동   38
#
# [425 rows x 3 columns]

# %%
seoul = tot.merge(hos, how='outer')
seoul
# Out:
#      자치구     동   출생   사망    전입    전출   혼인  이혼  병원수
# 0    강남구  개포1동   17   29   829   937   12  13    8
# 1    강남구  개포2동  152   57  9853  4191   61  28   26
# 2    강남구  개포4동   91   57  4408  3308   91  41   33
# 3    강남구  논현1동   93   81  5141  5967  112  45  250
# 4    강남구  논현2동  102   76  4171  4824   87  40  149
# ..   ...   ...  ...  ...   ...   ...  ...  ..  ...
# 420  중랑구  상봉2동  126   96  4437  4029  160  44   38
# 421  중랑구  신내1동  183  249  3719  4709   95  49   39
# 422  중랑구  신내2동  132  139  2182  2903   74  39   25
# 423  중랑구  중화1동  131  118  2619  3157   98  34   20
# 424  중랑구  중화2동   91  176  3464  3919   95  49   38
#
# [425 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns
from matplotlib import rc
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
from sklearn.preprocessing import MinMaxScaler
minmax = MinMaxScaler()

# %matplotlib inline

# %%
def elbow(data, length):
    sse = [] # sum of squre error 오차제곱합
    for i in range(1, length):
        kmeans = KMeans(n_clusters=i)
        kmeans.fit(data)
        # SSE 값 저장
        sse.append(kmeans.inertia_)
    plt.plot(range(1, length), sse, 'bo-')
    plt.title("elbow method")
    plt.xlabel("number of clusters")
    plt.ylabel("SSE")
    plt.show()

# %%
def visualize_silhouette(cluster_lists, X_features): 

    from sklearn.datasets import make_blobs
    from sklearn.cluster import KMeans
    from sklearn.metrics import silhouette_samples, silhouette_score

    import matplotlib.pyplot as plt
    import matplotlib.cm as cm
    import math

    # 입력값으로 클러스터링 갯수들을 리스트로 받아서, 각 갯수별로 클러스터링을 적용하고 실루엣 개수를 구함
    n_cols = len(cluster_lists)

    # plt.subplots()으로 리스트에 기재된 클러스터링 수만큼의 sub figures를 가지는 axs 생성 
    fig, axs = plt.subplots(figsize=(4*n_cols, 4), nrows=1, ncols=n_cols)

    # 리스트에 기재된 클러스터링 갯수들을 차례로 iteration 수행하면서 실루엣 개수 시각화
    for ind, n_cluster in enumerate(cluster_lists):

        # KMeans 클러스터링 수행하고, 실루엣 스코어와 개별 데이터의 실루엣 값 계산. 
        clusterer = KMeans(n_clusters = n_cluster, max_iter=500, random_state=0)
        cluster_labels = clusterer.fit_predict(X_features)

        sil_avg = silhouette_score(X_features, cluster_labels)
        sil_values = silhouette_samples(X_features, cluster_labels)

        y_lower = 10
        axs[ind].set_title('Number of Cluster : '+ str(n_cluster)+'\n' \
                          'Silhouette Score :' + str(round(sil_avg,3)) )
        axs[ind].set_xlabel("The silhouette coefficient values")
        axs[ind].set_ylabel("Cluster label")
        axs[ind].set_xlim([-0.1, 1])
        axs[ind].set_ylim([0, len(X_features) + (n_cluster + 1) * 10])
        axs[ind].set_yticks([])  # Clear the yaxis labels / ticks
        axs[ind].set_xticks([0, 0.2, 0.4, 0.6, 0.8, 1])

        # 클러스터링 갯수별로 fill_betweenx( )형태의 막대 그래프 표현. 
        for i in range(n_cluster):
            ith_cluster_sil_values = sil_values[cluster_labels==i]
            ith_cluster_sil_values.sort()

            size_cluster_i = ith_cluster_sil_values.shape[0]
            y_upper = y_lower + size_cluster_i

            color = cm.nipy_spectral(float(i) / n_cluster)
            axs[ind].fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_sil_values, \
                                facecolor=color, edgecolor=color, alpha=0.7)
            axs[ind].text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
            y_lower = y_upper + 10

        axs[ind].axvline(x=sil_avg, color="red", linestyle="--")

# %%
col = ['동','출생', '사망', '전입', '전출', '혼인', '이혼', '병원수']
s_kmean = seoul[col]
s_kmean.sort_values(['동'], inplace=True)
# Out:
# C:\Users\2106-017\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
elbow(s_kmean,30)
# Out:
# C:\Users\2106-017\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
a = list(range(2,20))
visualize_silhouette(a, s_kmean)

# %%
mmdata = minmax.fit_transform(s_kmean.drop('동', axis=1))
mmdata = pd.DataFrame(mmdata, columns=s_kmean.drop('동',axis=1).columns)
kmeans = KMeans(n_clusters=3, random_state=1234).fit(mmdata)
s_kmean['cluster'] = kmeans.labels_
s_kmean
# Out:
#         동   출생   사망    전입    전출   혼인  이혼  병원수  cluster
# 282  가락1동  326   66  5806  6542  115  34    6        1
# 283  가락2동  181   95  4201  4992  108  36   37        0
# 284  가락본동  191   85  3954  4800  122  38   86        0
# 109  가리봉동   27   76  1687  1788   45  19   12        2
# 125   가산동   81   89  6506  5835  167  45   65        0
# ..    ...  ...  ...   ...   ...  ...  ..  ...      ...
# 359   효창동   77   38  1612  1747   50  17   12        2
# 360   후암동   84  100  2070  2578   71  36   15        0
# 180  휘경1동   76   66  3048  2661   46  18   28        2
# 181  휘경2동   85  100  3869  3898   59  42    8        0
# 196   흑석동  167  158  4118  4677  109  35   43        1
#
# [425 rows x 9 columns]

# %%
add = pd.read_csv(r'C:\Users\2106-017\python\team_S\전체.csv', encoding='cp949')
add.drop('Unnamed: 0', axis=1, inplace=True)
add['cluster'] = s_kmean['cluster']

# %%
import folium

# %%
m_6 = folium.Map(
    location = (sum(add['위도'])/len(add['위도']), sum(add['경도'])/len(add['경도']) ),
    tiles='cartodbdark_matter',
    zoom_start = 11)
for i in range(add.shape[0]):
    
    if add['cluster'][i] == 0:
        color = 'blue'
    elif add['cluster'][i] == 1:
        color = 'red'
    elif add['cluster'][i] == 2:
        color = 'green'
    else :
        pass
    c = add.iat[i,9],add.iat[i,10]
    folium.Circle(c, popup=add['cluster'][i], color = color).add_to(m_6)

# %%
m_6
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
s_kmean.groupby(by = 'cluster').agg('mean')
# Out:
#                  출생          사망           전입           전출          혼인  \
# cluster
# 0        109.396907  114.994845  3346.979381  3697.907216   87.376289
# 1        191.902174  155.652174  5392.891304  5399.586957  145.847826
# 2         61.633094   63.978417  1962.064748  2232.187050   47.791367
#
#                 이혼        병원수
# cluster
# 0        37.855670  39.881443
# 1        53.565217  56.478261
# 2        19.388489  30.352518
